# %%
# Imports 
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # This line changes tensorflow log level and suppresses warnings
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy
from PIL import Image
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.python.framework import ops
from utils import *

np.random.seed(1)

# %%
# Load dataset
train_set_x_orig, train_set_y_orig, test_set_x_orig, test_set_y_orig, classes = load_signs_dataset()

# %%
# testing imported data
index = 0
plt.imshow(train_set_x_orig[index])

# %%
# Prepare the data
X_train = train_set_x_orig / 255
X_test = test_set_x_orig / 255

Y_train = convert_to_one_hot(train_set_y_orig, 6).T
Y_test = convert_to_one_hot(test_set_y_orig, 6).T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %%
# Forward Propagation
def conve_model(input_shape):

    input_image = tf.keras.Input(shape=input_shape)
    ## CONV2D: 8 filters 4x4, stride of 1, padding 'SAME'
    Z1 = tfl.Conv2D( filters = 8, kernel_size = (4, 4), strides = (1, 1), padding = 'same' )( input_image )
    ## RELU
    A1 = tfl.ReLU()(Z1)
    ## MAXPOOL: window 8x8, stride 8, padding 'SAME'
    P1 = tfl.MaxPool2D( pool_size = (8, 8), strides = (8, 8), padding = 'same' )(A1)
    ## CONV2D: 16 filters 2x2, stride 1, padding 'SAME'
    Z2 = tfl.Conv2D( filters = 16, kernel_size = (2, 2), strides = (1, 1), padding = 'same')(P1)
    ## RELU
    A2 = tfl.ReLU()(Z2)
    ## MAXPOOL: window 4x4, stride 4, padding 'SAME'
    P2 = tfl.MaxPool2D( pool_size = (4, 4), strides = (4, 4), padding = 'same')(A2)
    ## FLATTEN
    F = tfl.Flatten()(P2)
    ## Dense layer
    ## 6 neurons in output layer. Hint: one of the arguments should be "activation='softmax'" 
    outputs = tfl.Dense(units = 6, activation='softmax')(F)

    # Model
    model = tf.keras.Model(inputs = input_image, outputs = outputs)

    return model

# %%
# Model test
conv_model = conve_model((64, 64, 3))
conv_model.compile(optimizer='adam',loss='categorical_crossentropy', metrics=['accuracy'])
conv_model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 64, 64, 8)      │           392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_4 (ReLU)                  │ (None, 64, 64, 8)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 8, 8, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 16)       │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_5 (ReLU)                  │ (None, 8, 8, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 2, 2, 16)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,310 (5.12 KB)
#  Trainable params: 1,310 (5.12 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train)).batch(64)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test)).batch(64)
history = conv_model.fit(train_dataset, epochs=100, validation_data=test_dataset)
# Out:
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - accuracy: 0.1596 - loss: 1.8089 - val_accuracy: 0.1667 - val_loss: 1.7923
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1532 - loss: 1.7901 - val_accuracy: 0.1583 - val_loss: 1.7897
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.1905 - loss: 1.7844 - val_accuracy: 0.2333 - val_loss: 1.7849
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.2567 - loss: 1.7789 - val_accuracy: 0.2000 - val_loss: 1.7799
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.2485 - loss: 1.7713 - val_accuracy: 0.2083 - val_loss: 1.7734
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.2602 - loss: 1.7617 - val_accuracy: 0.2750 - val_loss: 1.7646
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.3273 - loss: 1.7483 - val_accuracy: 0.2667 - val_loss: 1.7534
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.3467 - loss: 1.7302 - val_accuracy: 0.3083 - val_loss: 1.7379
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.3811 - loss: 1.7070 - val_accuracy: 0.3500 - val_loss: 1.7184
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.3985 - loss: 1.6768 - val_accuracy: 0.3750 - val_loss: 1.6943
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4220 - loss: 1.6404 - val_accuracy: 0.4250 - val_loss: 1.6654
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.4411 - loss: 1.5997 - val_accuracy: 0.4167 - val_loss: 1.6331
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.4679 - loss: 1.5573 - val_accuracy: 0.4417 - val_loss: 1.6024
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4836 - loss: 1.5183 - val_accuracy: 0.4250 - val_loss: 1.5684
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.4877 - loss: 1.4798 - val_accuracy: 0.4333 - val_loss: 1.5390
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.4944 - loss: 1.4440 - val_accuracy: 0.4667 - val_loss: 1.5090
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5184 - loss: 1.4105 - val_accuracy: 0.4583 - val_loss: 1.4817
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5327 - loss: 1.3795 - val_accuracy: 0.4500 - val_loss: 1.4557
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5349 - loss: 1.3497 - val_accuracy: 0.4750 - val_loss: 1.4266
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5621 - loss: 1.3211 - val_accuracy: 0.4667 - val_loss: 1.4016
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5718 - loss: 1.2942 - val_accuracy: 0.4917 - val_loss: 1.3773
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5707 - loss: 1.2685 - val_accuracy: 0.5000 - val_loss: 1.3538
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5883 - loss: 1.2434 - val_accuracy: 0.4917 - val_loss: 1.3308
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.5953 - loss: 1.2192 - val_accuracy: 0.5083 - val_loss: 1.3090
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6006 - loss: 1.1963 - val_accuracy: 0.5083 - val_loss: 1.2888
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6066 - loss: 1.1744 - val_accuracy: 0.5333 - val_loss: 1.2682
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.6085 - loss: 1.1527 - val_accuracy: 0.5167 - val_loss: 1.2482
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6155 - loss: 1.1320 - val_accuracy: 0.5417 - val_loss: 1.2303
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6229 - loss: 1.1124 - val_accuracy: 0.5417 - val_loss: 1.2127
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6252 - loss: 1.0928 - val_accuracy: 0.5500 - val_loss: 1.1949
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6379 - loss: 1.0735 - val_accuracy: 0.5333 - val_loss: 1.1766
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6457 - loss: 1.0543 - val_accuracy: 0.5750 - val_loss: 1.1592
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6509 - loss: 1.0363 - val_accuracy: 0.5750 - val_loss: 1.1428
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6630 - loss: 1.0193 - val_accuracy: 0.5750 - val_loss: 1.1259
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.6779 - loss: 1.0020 - val_accuracy: 0.5833 - val_loss: 1.1103
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6801 - loss: 0.9857 - val_accuracy: 0.6000 - val_loss: 1.0960
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6902 - loss: 0.9700 - val_accuracy: 0.6167 - val_loss: 1.0811
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.6965 - loss: 0.9543 - val_accuracy: 0.6083 - val_loss: 1.0678
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.6885 - loss: 0.9392 - val_accuracy: 0.6083 - val_loss: 1.0525
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7060 - loss: 0.9267 - val_accuracy: 0.6250 - val_loss: 1.0396
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7140 - loss: 0.9119 - val_accuracy: 0.6250 - val_loss: 1.0250
# Epoch 42/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7182 - loss: 0.8978 - val_accuracy: 0.6333 - val_loss: 1.0119
# Epoch 43/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7212 - loss: 0.8844 - val_accuracy: 0.6333 - val_loss: 0.9991
# Epoch 44/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7209 - loss: 0.8723 - val_accuracy: 0.6250 - val_loss: 0.9862
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7217 - loss: 0.8591 - val_accuracy: 0.6333 - val_loss: 0.9739
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7276 - loss: 0.8471 - val_accuracy: 0.6333 - val_loss: 0.9613
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7365 - loss: 0.8354 - val_accuracy: 0.6333 - val_loss: 0.9502
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7287 - loss: 0.8238 - val_accuracy: 0.6417 - val_loss: 0.9381
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7351 - loss: 0.8127 - val_accuracy: 0.6417 - val_loss: 0.9276
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.7363 - loss: 0.8020 - val_accuracy: 0.6500 - val_loss: 0.9162
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7374 - loss: 0.7915 - val_accuracy: 0.6667 - val_loss: 0.9049
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7370 - loss: 0.7812 - val_accuracy: 0.6667 - val_loss: 0.8942
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7420 - loss: 0.7710 - val_accuracy: 0.6833 - val_loss: 0.8838
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.7504 - loss: 0.7610 - val_accuracy: 0.6833 - val_loss: 0.8735
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7608 - loss: 0.7512 - val_accuracy: 0.6917 - val_loss: 0.8641
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7624 - loss: 0.7419 - val_accuracy: 0.7000 - val_loss: 0.8544
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7643 - loss: 0.7325 - val_accuracy: 0.7000 - val_loss: 0.8448
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7666 - loss: 0.7225 - val_accuracy: 0.7000 - val_loss: 0.8353
# Epoch 59/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7669 - loss: 0.7134 - val_accuracy: 0.7167 - val_loss: 0.8266
# Epoch 60/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7704 - loss: 0.7043 - val_accuracy: 0.7167 - val_loss: 0.8179
# Epoch 61/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7722 - loss: 0.6955 - val_accuracy: 0.7250 - val_loss: 0.8095
# Epoch 62/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7732 - loss: 0.6870 - val_accuracy: 0.7250 - val_loss: 0.8013
# Epoch 63/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7736 - loss: 0.6786 - val_accuracy: 0.7250 - val_loss: 0.7943
# Epoch 64/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7745 - loss: 0.6707 - val_accuracy: 0.7250 - val_loss: 0.7870
# Epoch 65/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7847 - loss: 0.6622 - val_accuracy: 0.7250 - val_loss: 0.7799
# Epoch 66/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7851 - loss: 0.6543 - val_accuracy: 0.7250 - val_loss: 0.7735
# Epoch 67/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7842 - loss: 0.6467 - val_accuracy: 0.7333 - val_loss: 0.7663
# Epoch 68/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7874 - loss: 0.6394 - val_accuracy: 0.7500 - val_loss: 0.7597
# Epoch 69/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7873 - loss: 0.6319 - val_accuracy: 0.7500 - val_loss: 0.7518
# Epoch 70/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7911 - loss: 0.6246 - val_accuracy: 0.7500 - val_loss: 0.7457
# Epoch 71/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7946 - loss: 0.6170 - val_accuracy: 0.7500 - val_loss: 0.7384
# Epoch 72/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.7953 - loss: 0.6102 - val_accuracy: 0.7583 - val_loss: 0.7317
# Epoch 73/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7971 - loss: 0.6036 - val_accuracy: 0.7583 - val_loss: 0.7257
# Epoch 74/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7971 - loss: 0.5970 - val_accuracy: 0.7667 - val_loss: 0.7197
# Epoch 75/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8010 - loss: 0.5906 - val_accuracy: 0.7667 - val_loss: 0.7140
# Epoch 76/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8019 - loss: 0.5843 - val_accuracy: 0.7750 - val_loss: 0.7083
# Epoch 77/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8060 - loss: 0.5778 - val_accuracy: 0.7667 - val_loss: 0.7017
# Epoch 78/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8044 - loss: 0.5721 - val_accuracy: 0.7667 - val_loss: 0.6983
# Epoch 79/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8060 - loss: 0.5659 - val_accuracy: 0.7667 - val_loss: 0.6923
# Epoch 80/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8083 - loss: 0.5603 - val_accuracy: 0.7667 - val_loss: 0.6864
# Epoch 81/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8106 - loss: 0.5545 - val_accuracy: 0.7667 - val_loss: 0.6834
# Epoch 82/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8074 - loss: 0.5488 - val_accuracy: 0.7667 - val_loss: 0.6772
# Epoch 83/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8130 - loss: 0.5436 - val_accuracy: 0.7750 - val_loss: 0.6721
# Epoch 84/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8187 - loss: 0.5382 - val_accuracy: 0.7750 - val_loss: 0.6678
# Epoch 85/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8248 - loss: 0.5329 - val_accuracy: 0.7750 - val_loss: 0.6627
# Epoch 86/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8242 - loss: 0.5283 - val_accuracy: 0.7750 - val_loss: 0.6580
# Epoch 87/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8256 - loss: 0.5229 - val_accuracy: 0.7750 - val_loss: 0.6531
# Epoch 88/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8271 - loss: 0.5186 - val_accuracy: 0.7750 - val_loss: 0.6495
# Epoch 89/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8290 - loss: 0.5133 - val_accuracy: 0.7750 - val_loss: 0.6442
# Epoch 90/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8278 - loss: 0.5088 - val_accuracy: 0.7750 - val_loss: 0.6398
# Epoch 91/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8299 - loss: 0.5039 - val_accuracy: 0.7750 - val_loss: 0.6349
# Epoch 92/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8319 - loss: 0.4996 - val_accuracy: 0.7667 - val_loss: 0.6322
# Epoch 93/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8296 - loss: 0.4946 - val_accuracy: 0.7667 - val_loss: 0.6274
# Epoch 94/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8356 - loss: 0.4901 - val_accuracy: 0.7667 - val_loss: 0.6228
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8367 - loss: 0.4855 - val_accuracy: 0.7917 - val_loss: 0.6184
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8410 - loss: 0.4813 - val_accuracy: 0.7917 - val_loss: 0.6155
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8471 - loss: 0.4771 - val_accuracy: 0.7917 - val_loss: 0.6110
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8475 - loss: 0.4729 - val_accuracy: 0.8000 - val_loss: 0.6079
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.8496 - loss: 0.4686 - val_accuracy: 0.8000 - val_loss: 0.6043
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.8525 - loss: 0.4646 - val_accuracy: 0.8000 - val_loss: 0.6004

# %%
# The history.history["loss"] entry is a dictionary with as many values as epochs that the
# model was trained on. 
df_loss_acc = pd.DataFrame(history.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# /var/folders/8w/93ljccqs0md6xgg68zkvyxb80000gn/T/ipykernel_6192/973814028.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# /var/folders/8w/93ljccqs0md6xgg68zkvyxb80000gn/T/ipykernel_6192/973814028.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Accuracy')]
